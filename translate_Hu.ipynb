# %%
import os
import pandas as pd
result = pd.DataFrame()

df = pd.read_csv("translate.csv","|")

# %%
for i in range(len(df.megye)):
    df.megye[i] = df.megye[i].split(",")[1]
    if(df.megye[i] == " AB"):
        df.megye[i] = "Alba"
    else:
        if(df.megye[i] == " AR"):
            df.megye[i] = "Arad"
        else:
            if(df.megye[i] == " BH"):
                df.megye[i] = "Bihor"
            else:
                if(df.megye[i] == " BN"):
                    df.megye[i] = "Bistrita-Nasaud"
                else:
                    if(df.megye[i] == " BV"):
                        df.megye[i] = "Brasov"
                    else:
                        if(df.megye[i] == " BN"):
                            df.megye[i] = "Bistrita-Nasaud"
                        else:
                            if(df.megye[i] == " CS"):
                                df.megye[i] = "Caras-Severin"
                            else:
                                if(df.megye[i] == " CJ"):
                                    df.megye[i] = "Cluj"
                                else:
                                    if(df.megye[i] == " CV"):
                                        df.megye[i] = "Covasna"
                                    else:
                                        if(df.megye[i] == " HR"):
                                            df.megye[i] = "Harghita"
                                        else:
                                            if(df.megye[i] == " HD"):
                                                df.megye[i] = "Hunedoara"
                                            else:
                                                if(df.megye[i] == " MM"):
                                                    df.megye[i] = "Maramures"
                                                else:
                                                    if(df.megye[i] == " MS"):
                                                        df.megye[i] = "Mures"
                                                    else:
                                                        if(df.megye[i] == " SJ"):
                                                            df.megye[i] = "Salaj"
                                                        else:
                                                            if(df.megye[i] == " SM"):
                                                                df.megye[i] = "Satu Mare"
                                                            else:
                                                                if(df.megye[i] == " SB"):
                                                                    df.megye[i] = "Sibiu"
                                                                else:
                                                                    if(df.megye[i] == " TM"):
                                                                        df.megye[i] = "Timis"

# %%
df
# Out:
#                     falu            megye             hun
# 0                 Abram             Bihor        Érábrány
# 1               Abramut             Bihor    Vedresábrány
# 2                 Abrud              Alba      Abrudbánya
# 3             Abrud-Sat              Alba      Abrudfalva
# 4                Abucea         Hunedoara          Abucsa
# 5                  Abud             Mures     Székelyabod
# 6                  Abus             Mures       Abosfalva
# 7               Acatari             Mures       Ákosfalva
# 8                  Acas         Satu Mare            Ákos
# 9           Achimitesti              Alba             NaN
# 10               Aciliu             Sibiu         Ecsellő
# 11                Aciua         Satu Mare      Balotafalu
# 12               Aciuta              Arad        Ácsfalva
# 13              Acmariu              Alba           Akmár
# 14                Acris            Brasov      Egrestelep
# ...

# %%
for i in range(len(df.falu)):
    df.falu[i] = df.falu[i].lower()

# %%
df.to_csv("translate_HU.csv",index=False, sep = "|")
